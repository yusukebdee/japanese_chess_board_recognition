# %%
import cv2 as cv
import numpy as np
from PIL import Image
import os

# %%
class CvOverlayImage(object):

    def __init__(self):
        pass

    @classmethod
    def overlay(
            cls,
            cv_background_image,
            cv_overlay_image,
            point,
    ):
        overlay_height, overlay_width = cv_overlay_image.shape[:2]

        #Convert OpenCV format image to PIL format (including α value)
        #background image
        cv_rgb_bg_image = cv.cvtColor(cv_background_image, cv.COLOR_BGR2RGB)
        pil_rgb_bg_image = Image.fromarray(cv_rgb_bg_image)
        pil_rgba_bg_image = pil_rgb_bg_image.convert('RGBA')
        # overlay image
        cv_rgb_ol_image = cv.cvtColor(cv_overlay_image, cv.COLOR_BGRA2RGBA)
        pil_rgb_ol_image = Image.fromarray(cv_rgb_ol_image)
        pil_rgba_ol_image = pil_rgb_ol_image.convert('RGBA')

        #Composite() requires images of the same size, so prepare an image for compositing
        pil_rgba_bg_temp = Image.new('RGBA', pil_rgba_bg_image.size,
                                     (255, 255, 255, 0))
        #Specify coordinates and superimpose
        pil_rgba_bg_temp.paste(pil_rgba_ol_image, point, pil_rgba_ol_image)
        result_image = \
            Image.alpha_composite(pil_rgba_bg_image, pil_rgba_bg_temp)

        #Convert to OpenCV format image
        cv_bgr_result_image = cv.cvtColor(
            np.asarray(result_image), cv.COLOR_RGBA2BGRA)

        return cv_bgr_result_image

# %%
#Input "koma" data 
with open("./input/label0.txt", "r", encoding="utf-8") as f:
    list0 = f.readlines()
    print(list0)
# Out:
# ['b to\n', 'b to\n', 'w gi\n', 'b ou\n', 'b ou\n', 'b fu\n', 'b to\n', 'b to\n', 'w ny\n', 'blank\n', 'w um\n', 'b to\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'b to\n', 'w ny\n', 'b to\n', 'w fu\n', 'b ou\n', 'w um\n', 'b ou\n', 'b ou\n', 'w ka\n', 'b to\n', 'b to\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'w to\n', 'b ka\n', 'b fu\n', 'b ou\n', 'b fu\n', 'w um\n', 'b um\n', 'b to\n', 'b to\n', 'blank\n', 'w to\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'blank\n', 'b to\n', 'w ny\n', 'w to\n', 'b to\n', 'b to\n', 'b ki\n', 'b ou\n', 'b fu\n', 'b to\n', 'b to\n', 'w to\n']

# %%
#data shaping
list_upper = []
list_ = []
list2_ = []
list3_ = []
for str in list0:
    list_upper = str.upper()
    list_ = list_upper.replace(' ', '_')
    list2_ = list_.strip("\n")
    list3_.append(list2_)
#print(list0)
print(list3_)
# Out:
# ['B_TO', 'B_TO', 'W_GI', 'B_OU', 'B_OU', 'B_FU', 'B_TO', 'B_TO', 'W_NY', 'BLANK', 'W_UM', 'B_TO', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'B_TO', 'W_NY', 'B_TO', 'W_FU', 'B_OU', 'W_UM', 'B_OU', 'B_OU', 'W_KA', 'B_TO', 'B_TO', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'W_TO', 'B_KA', 'B_FU', 'B_OU', 'B_FU', 'W_UM', 'B_UM', 'B_TO', 'B_TO', 'BLANK', 'W_TO', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'BLANK', 'B_TO', 'W_NY', 'W_TO', 'B_TO', 'B_TO', 'B_KI', 'B_OU', 'B_FU', 'B_TO', 'B_TO', 'W_TO']

# %%
#cretate piece Map
pieceMap = {            
                'B_FU': 'sgl08.png', 'W_FU': 'sgl38.png',
                'B_TO': 'sgl18.png', 'W_TO': 'sgl48.png',
                'B_KY': 'sgl07.png', 'W_KY': 'sgl37.png',
                'B_NY': 'sgl17.png', 'W_NY': 'sgl47.png',
                'B_KE': 'sgl06.png', 'W_KE': 'sgl36.png',
                'B_NK': 'sgl16.png', 'W_NK': 'sgl46.png',
                'B_GI': 'sgl05.png', 'W_GI': 'sgl35.png',
                'B_NG': 'sgl15.png', 'W_NG': 'sgl45.png',
                'B_KI': 'sgl04.png', 'W_KI': 'sgl34.png',
                'B_KA': 'sgl03.png', 'W_KA': 'sgl33.png',
                'B_UM': 'sgl13.png', 'W_UM': 'sgl43.png',
                'B_HI': 'sgl02.png', 'W_HI': 'sgl32.png',
                'B_RY': 'sgl12.png', 'W_RY': 'sgl42.png',
                'B_OU': 'sgl01.png', 'W_OU': 'sgl31.png',
                'BLANK':'board_w.png',
        }

# %%
#create "koma" image 
koma_ = []
for p in list3_:
    koma_.append(pieceMap[p])

print(koma_)
# Out:
# ['sgl18.png', 'sgl18.png', 'sgl35.png', 'sgl01.png', 'sgl01.png', 'sgl08.png', 'sgl18.png', 'sgl18.png', 'sgl47.png', 'board_w.png', 'sgl43.png', 'sgl18.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'sgl18.png', 'sgl47.png', 'sgl18.png', 'sgl38.png', 'sgl01.png', 'sgl43.png', 'sgl01.png', 'sgl01.png', 'sgl33.png', 'sgl18.png', 'sgl18.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'sgl48.png', 'sgl03.png', 'sgl08.png', 'sgl01.png', 'sgl08.png', 'sgl43.png', 'sgl13.png', 'sgl18.png', 'sgl18.png', 'board_w.png', 'sgl48.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'board_w.png', 'sgl18.png'
# ...

# %%
#xy coordinate on shogi board 1
x0 = 0
y0 = 0
x = []
y = []
for i in range(9):
    x0 = 31 + 60*i
    x.append(x0)
print(x)

for j in range(9):
    y0 = 31 + 65*j
    y.append(y0)
print(y)
# Out:
# [31, 91, 151, 211, 271, 331, 391, 451, 511]
# [31, 96, 161, 226, 291, 356, 421, 486, 551]

# %%
#xy coordinate on shogi board 2
point_list = []
for l in y:
    for k in x:
        point_list.append([k,l])
        
print(point_list)
print(np.shape(point_list))
# Out:
# [[31, 31], [91, 31], [151, 31], [211, 31], [271, 31], [331, 31], [391, 31], [451, 31], [511, 31], [31, 96], [91, 96], [151, 96], [211, 96], [271, 96], [331, 96], [391, 96], [451, 96], [511, 96], [31, 161], [91, 161], [151, 161], [211, 161], [271, 161], [331, 161], [391, 161], [451, 161], [511, 161], [31, 226], [91, 226], [151, 226], [211, 226], [271, 226], [331, 226], [391, 226], [451, 226], [511, 226], [31, 291], [91, 291], [151, 291], [211, 291], [271, 291], [331, 291], [391, 291], [451, 291], [511, 291], [31, 356], [91, 356], [151, 356], [211, 356], [271, 356], [331, 356], [391, 356], [451, 356], [511, 356], [31, 421], [91, 421], [151, 421], [211, 421], [271, 421], [331, 421], [391, 421], [451, 421], [511, 421], [31, 486], [91, 486], [151, 486], [211, 486], [271, 486], [331, 486], [391, 486], [451, 486], [511, 486], [31, 551], [91, 551], [151, 551], [211, 551], [271, 551], [331, 551], [391, 551], [451, 551], [511, 551]]
# (81, 2)

# %%
#create japanese chess board image
if __name__ == '__main__':
    cv_background_image = cv.imread("./koma_image/japanese-chess-b02.jpg")
    cv_overlay_image0 = cv.imread('{}'.format(koma_[0]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image0 = cv.resize(cv_overlay_image0, (58, 58))
    cv_overlay_image1 = cv.imread('{}'.format(koma_[1]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image1 = cv.resize(cv_overlay_image1, (58, 58))
    cv_overlay_image2 = cv.imread('{}'.format(koma_[2]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image2 = cv.resize(cv_overlay_image2, (58, 58))
    cv_overlay_image3 = cv.imread('{}'.format(koma_[3]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image3 = cv.resize(cv_overlay_image3, (58, 58))
    cv_overlay_image4 = cv.imread('{}'.format(koma_[4]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image4 = cv.resize(cv_overlay_image4, (58, 58))
    cv_overlay_image5 = cv.imread('{}'.format(koma_[5]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image5 = cv.resize(cv_overlay_image5, (58, 58))
    cv_overlay_image6 = cv.imread('{}'.format(koma_[6]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image6 = cv.resize(cv_overlay_image6, (58, 58))
    cv_overlay_image7 = cv.imread('{}'.format(koma_[7]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image7 = cv.resize(cv_overlay_image7, (58, 58))
    cv_overlay_image8 = cv.imread('{}'.format(koma_[8]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image8 = cv.resize(cv_overlay_image8, (58, 58))
    cv_overlay_image9 = cv.imread('{}'.format(koma_[9]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image9 = cv.resize(cv_overlay_image9, (58, 58))
    cv_overlay_image10 = cv.imread('{}'.format(koma_[10]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image10 = cv.resize(cv_overlay_image10, (58, 58))
    cv_overlay_image11 = cv.imread('{}'.format(koma_[11]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image11 = cv.resize(cv_overlay_image11, (58, 58))
    cv_overlay_image12 = cv.imread('{}'.format(koma_[12]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image12 = cv.resize(cv_overlay_image12, (58, 58))
    cv_overlay_image13 = cv.imread('{}'.format(koma_[13]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image13 = cv.resize(cv_overlay_image13, (58, 58))
    cv_overlay_image14 = cv.imread('{}'.format(koma_[14]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image14 = cv.resize(cv_overlay_image14, (58, 58))
    cv_overlay_image15 = cv.imread('{}'.format(koma_[15]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image15 = cv.resize(cv_overlay_image15, (58, 58))
    cv_overlay_image16 = cv.imread('{}'.format(koma_[16]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image16 = cv.resize(cv_overlay_image16, (58, 58))
    cv_overlay_image17 = cv.imread('{}'.format(koma_[17]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image17 = cv.resize(cv_overlay_image17, (58, 58))
    cv_overlay_image18 = cv.imread('{}'.format(koma_[18]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image18 = cv.resize(cv_overlay_image18, (58, 58))
    cv_overlay_image19 = cv.imread('{}'.format(koma_[19]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image19 = cv.resize(cv_overlay_image19, (58, 58))
    cv_overlay_image20 = cv.imread('{}'.format(koma_[20]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image20 = cv.resize(cv_overlay_image20, (58, 58))
    cv_overlay_image21 = cv.imread('{}'.format(koma_[21]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image21 = cv.resize(cv_overlay_image21, (58, 58))
    cv_overlay_image22 = cv.imread('{}'.format(koma_[22]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image22 = cv.resize(cv_overlay_image22, (58, 58))
    cv_overlay_image23 = cv.imread('{}'.format(koma_[23]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image23 = cv.resize(cv_overlay_image23, (58, 58))
    cv_overlay_image24 = cv.imread('{}'.format(koma_[24]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image24 = cv.resize(cv_overlay_image24, (58, 58))
    cv_overlay_image25 = cv.imread('{}'.format(koma_[25]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image25 = cv.resize(cv_overlay_image25, (58, 58))
    cv_overlay_image26 = cv.imread('{}'.format(koma_[26]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image26 = cv.resize(cv_overlay_image26, (58, 58))
    cv_overlay_image27 = cv.imread('{}'.format(koma_[27]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image27 = cv.resize(cv_overlay_image27, (58, 58))
    cv_overlay_image28 = cv.imread('{}'.format(koma_[28]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image28 = cv.resize(cv_overlay_image28, (58, 58))
    cv_overlay_image29 = cv.imread('{}'.format(koma_[29]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image29 = cv.resize(cv_overlay_image29, (58, 58))
    cv_overlay_image30 = cv.imread('{}'.format(koma_[30]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image30 = cv.resize(cv_overlay_image30, (58, 58))
    cv_overlay_image31 = cv.imread('{}'.format(koma_[31]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image31 = cv.resize(cv_overlay_image31, (58, 58))
    cv_overlay_image32 = cv.imread('{}'.format(koma_[32]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image32 = cv.resize(cv_overlay_image32, (58, 58))
    cv_overlay_image33 = cv.imread('{}'.format(koma_[33]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image33 = cv.resize(cv_overlay_image33, (58, 58))
    cv_overlay_image34 = cv.imread('{}'.format(koma_[34]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image34 = cv.resize(cv_overlay_image34, (58, 58))
    cv_overlay_image35 = cv.imread('{}'.format(koma_[35]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image35 = cv.resize(cv_overlay_image35, (58, 58))
    cv_overlay_image36 = cv.imread('{}'.format(koma_[36]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image36 = cv.resize(cv_overlay_image36, (58, 58))
    cv_overlay_image37 = cv.imread('{}'.format(koma_[37]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image37 = cv.resize(cv_overlay_image37, (58, 58))
    cv_overlay_image38 = cv.imread('{}'.format(koma_[38]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image38 = cv.resize(cv_overlay_image38, (58, 58))
    cv_overlay_image39 = cv.imread('{}'.format(koma_[39]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image39 = cv.resize(cv_overlay_image39, (58, 58))
    cv_overlay_image40 = cv.imread('{}'.format(koma_[40]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image40 = cv.resize(cv_overlay_image40, (58, 58))
    cv_overlay_image41 = cv.imread('{}'.format(koma_[41]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image41 = cv.resize(cv_overlay_image41, (58, 58))
    cv_overlay_image42 = cv.imread('{}'.format(koma_[42]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image42 = cv.resize(cv_overlay_image42, (58, 58))
    cv_overlay_image43 = cv.imread('{}'.format(koma_[43]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image43 = cv.resize(cv_overlay_image43, (58, 58))
    cv_overlay_image44 = cv.imread('{}'.format(koma_[44]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image44 = cv.resize(cv_overlay_image44, (58, 58))
    cv_overlay_image45 = cv.imread('{}'.format(koma_[45]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image45 = cv.resize(cv_overlay_image45, (58, 58))
    cv_overlay_image46 = cv.imread('{}'.format(koma_[46]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image46 = cv.resize(cv_overlay_image46, (58, 58))
    cv_overlay_image47 = cv.imread('{}'.format(koma_[47]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image47 = cv.resize(cv_overlay_image47, (58, 58))
    cv_overlay_image48 = cv.imread('{}'.format(koma_[48]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image48 = cv.resize(cv_overlay_image48, (58, 58))
    cv_overlay_image49 = cv.imread('{}'.format(koma_[49]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image49 = cv.resize(cv_overlay_image49, (58, 58))
    cv_overlay_image50 = cv.imread('{}'.format(koma_[50]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image50 = cv.resize(cv_overlay_image50, (58, 58))
    cv_overlay_image51 = cv.imread('{}'.format(koma_[51]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image51 = cv.resize(cv_overlay_image51, (58, 58))
    cv_overlay_image52 = cv.imread('{}'.format(koma_[52]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image52 = cv.resize(cv_overlay_image52, (58, 58))
    cv_overlay_image53 = cv.imread('{}'.format(koma_[53]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image53 = cv.resize(cv_overlay_image53, (58, 58))
    cv_overlay_image54 = cv.imread('{}'.format(koma_[54]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image54 = cv.resize(cv_overlay_image54, (58, 58))
    cv_overlay_image55 = cv.imread('{}'.format(koma_[55]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image55 = cv.resize(cv_overlay_image55, (58, 58))
    cv_overlay_image56 = cv.imread('{}'.format(koma_[56]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image56 = cv.resize(cv_overlay_image56, (58, 58))
    cv_overlay_image57 = cv.imread('{}'.format(koma_[57]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image57 = cv.resize(cv_overlay_image57, (58, 58))
    cv_overlay_image58 = cv.imread('{}'.format(koma_[58]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image58 = cv.resize(cv_overlay_image58, (58, 58))
    cv_overlay_image59 = cv.imread('{}'.format(koma_[59]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image59 = cv.resize(cv_overlay_image59, (58, 58))
    cv_overlay_image60 = cv.imread('{}'.format(koma_[60]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image60 = cv.resize(cv_overlay_image60, (58, 58))
    cv_overlay_image61 = cv.imread('{}'.format(koma_[61]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image61 = cv.resize(cv_overlay_image61, (58, 58))
    cv_overlay_image62 = cv.imread('{}'.format(koma_[62]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image62 = cv.resize(cv_overlay_image62, (58, 58))
    cv_overlay_image63 = cv.imread('{}'.format(koma_[63]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image63 = cv.resize(cv_overlay_image63, (58, 58))
    cv_overlay_image64 = cv.imread('{}'.format(koma_[64]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image64 = cv.resize(cv_overlay_image64, (58, 58))
    cv_overlay_image65 = cv.imread('{}'.format(koma_[65]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image65 = cv.resize(cv_overlay_image65, (58, 58))
    cv_overlay_image66 = cv.imread('{}'.format(koma_[66]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image66 = cv.resize(cv_overlay_image66, (58, 58))
    cv_overlay_image67 = cv.imread('{}'.format(koma_[67]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image67 = cv.resize(cv_overlay_image67, (58, 58))
    cv_overlay_image68 = cv.imread('{}'.format(koma_[68]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image68 = cv.resize(cv_overlay_image68, (58, 58))
    cv_overlay_image69 = cv.imread('{}'.format(koma_[69]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image69 = cv.resize(cv_overlay_image69, (58, 58))
    cv_overlay_image70 = cv.imread('{}'.format(koma_[70]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image70 = cv.resize(cv_overlay_image70, (58, 58))
    cv_overlay_image71 = cv.imread('{}'.format(koma_[71]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image71 = cv.resize(cv_overlay_image71, (58, 58))
    cv_overlay_image72 = cv.imread('{}'.format(koma_[72]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image72 = cv.resize(cv_overlay_image72, (58, 58))
    cv_overlay_image73 = cv.imread('{}'.format(koma_[73]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image73 = cv.resize(cv_overlay_image73, (58, 58))
    cv_overlay_image74 = cv.imread('{}'.format(koma_[74]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image74 = cv.resize(cv_overlay_image74, (58, 58))
    cv_overlay_image75 = cv.imread('{}'.format(koma_[75]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image75 = cv.resize(cv_overlay_image75, (58, 58))
    cv_overlay_image76 = cv.imread('{}'.format(koma_[76]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image76 = cv.resize(cv_overlay_image76, (58, 58))
    cv_overlay_image77 = cv.imread('{}'.format(koma_[77]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image77 = cv.resize(cv_overlay_image77, (58, 58))
    cv_overlay_image78 = cv.imread('{}'.format(koma_[78]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image78 = cv.resize(cv_overlay_image78, (58, 58))
    cv_overlay_image79 = cv.imread('{}'.format(koma_[79]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image79 = cv.resize(cv_overlay_image79, (58, 58))
    cv_overlay_image80 = cv.imread('{}'.format(koma_[80]),cv.IMREAD_UNCHANGED) 
    cv_overlay_image80 = cv.resize(cv_overlay_image80, (58, 58))
    
    image = CvOverlayImage.overlay(cv_background_image, cv_overlay_image0,point_list[0])
    image = CvOverlayImage.overlay(image, cv_overlay_image1,point_list[1])
    image = CvOverlayImage.overlay(image, cv_overlay_image2,point_list[2])
    image = CvOverlayImage.overlay(image, cv_overlay_image3,point_list[3])
    image = CvOverlayImage.overlay(image, cv_overlay_image4,point_list[4])
    image = CvOverlayImage.overlay(image, cv_overlay_image5,point_list[5])
    image = CvOverlayImage.overlay(image, cv_overlay_image6,point_list[6])
    image = CvOverlayImage.overlay(image, cv_overlay_image7,point_list[7])
    image = CvOverlayImage.overlay(image, cv_overlay_image8,point_list[8])    
    image = CvOverlayImage.overlay(image, cv_overlay_image9,point_list[9])
    image = CvOverlayImage.overlay(image, cv_overlay_image10,point_list[10])
    image = CvOverlayImage.overlay(image, cv_overlay_image11,point_list[11])
    image = CvOverlayImage.overlay(image, cv_overlay_image12,point_list[12])    
    image = CvOverlayImage.overlay(image, cv_overlay_image13,point_list[13])
    image = CvOverlayImage.overlay(image, cv_overlay_image14,point_list[14])
    image = CvOverlayImage.overlay(image, cv_overlay_image15,point_list[15])
    image = CvOverlayImage.overlay(image, cv_overlay_image16,point_list[16])
    image = CvOverlayImage.overlay(image, cv_overlay_image17,point_list[17])
    image = CvOverlayImage.overlay(image, cv_overlay_image18,point_list[18])
    image = CvOverlayImage.overlay(image, cv_overlay_image19,point_list[19])
    image = CvOverlayImage.overlay(image, cv_overlay_image20,point_list[20])
    image = CvOverlayImage.overlay(image, cv_overlay_image21,point_list[21])
    image = CvOverlayImage.overlay(image, cv_overlay_image22,point_list[22])
    image = CvOverlayImage.overlay(image, cv_overlay_image23,point_list[23])
    image = CvOverlayImage.overlay(image, cv_overlay_image24,point_list[24])    
    image = CvOverlayImage.overlay(image, cv_overlay_image25,point_list[25])
    image = CvOverlayImage.overlay(image, cv_overlay_image26,point_list[26])
    image = CvOverlayImage.overlay(image, cv_overlay_image27,point_list[27])
    image = CvOverlayImage.overlay(image, cv_overlay_image28,point_list[28])    
    image = CvOverlayImage.overlay(image, cv_overlay_image29,point_list[29])
    image = CvOverlayImage.overlay(image, cv_overlay_image30,point_list[30])
    image = CvOverlayImage.overlay(image, cv_overlay_image31,point_list[31])
    image = CvOverlayImage.overlay(image, cv_overlay_image32,point_list[32])
    image = CvOverlayImage.overlay(image, cv_overlay_image33,point_list[33])
    image = CvOverlayImage.overlay(image, cv_overlay_image34,point_list[34])
    image = CvOverlayImage.overlay(image, cv_overlay_image35,point_list[35])
    image = CvOverlayImage.overlay(image, cv_overlay_image36,point_list[36])
    image = CvOverlayImage.overlay(image, cv_overlay_image37,point_list[37])
    image = CvOverlayImage.overlay(image, cv_overlay_image38,point_list[38])
    image = CvOverlayImage.overlay(image, cv_overlay_image39,point_list[39])
    image = CvOverlayImage.overlay(image, cv_overlay_image40,point_list[40])    
    image = CvOverlayImage.overlay(image, cv_overlay_image41,point_list[41])
    image = CvOverlayImage.overlay(image, cv_overlay_image42,point_list[42])
    image = CvOverlayImage.overlay(image, cv_overlay_image43,point_list[43])
    image = CvOverlayImage.overlay(image, cv_overlay_image44,point_list[44])    
    image = CvOverlayImage.overlay(image, cv_overlay_image45,point_list[45])
    image = CvOverlayImage.overlay(image, cv_overlay_image46,point_list[46])
    image = CvOverlayImage.overlay(image, cv_overlay_image47,point_list[47])
    image = CvOverlayImage.overlay(image, cv_overlay_image48,point_list[48])
    image = CvOverlayImage.overlay(image, cv_overlay_image49,point_list[49])
    image = CvOverlayImage.overlay(image, cv_overlay_image50,point_list[50])
    image = CvOverlayImage.overlay(image, cv_overlay_image51,point_list[51])
    image = CvOverlayImage.overlay(image, cv_overlay_image52,point_list[52])
    image = CvOverlayImage.overlay(image, cv_overlay_image53,point_list[53])
    image = CvOverlayImage.overlay(image, cv_overlay_image54,point_list[54])
    image = CvOverlayImage.overlay(image, cv_overlay_image55,point_list[55])
    image = CvOverlayImage.overlay(image, cv_overlay_image56,point_list[56])    
    image = CvOverlayImage.overlay(image, cv_overlay_image57,point_list[57])
    image = CvOverlayImage.overlay(image, cv_overlay_image58,point_list[58])
    image = CvOverlayImage.overlay(image, cv_overlay_image59,point_list[59])
    image = CvOverlayImage.overlay(image, cv_overlay_image60,point_list[60])    
    image = CvOverlayImage.overlay(image, cv_overlay_image61,point_list[61])
    image = CvOverlayImage.overlay(image, cv_overlay_image62,point_list[62])
    image = CvOverlayImage.overlay(image, cv_overlay_image63,point_list[63])
    image = CvOverlayImage.overlay(image, cv_overlay_image64,point_list[64])
    image = CvOverlayImage.overlay(image, cv_overlay_image65,point_list[65])
    image = CvOverlayImage.overlay(image, cv_overlay_image66,point_list[66])
    image = CvOverlayImage.overlay(image, cv_overlay_image67,point_list[67])
    image = CvOverlayImage.overlay(image, cv_overlay_image68,point_list[68])
    image = CvOverlayImage.overlay(image, cv_overlay_image69,point_list[69])
    image = CvOverlayImage.overlay(image, cv_overlay_image70,point_list[70])
    image = CvOverlayImage.overlay(image, cv_overlay_image71,point_list[71])
    image = CvOverlayImage.overlay(image, cv_overlay_image72,point_list[72])    
    image = CvOverlayImage.overlay(image, cv_overlay_image73,point_list[73])
    image = CvOverlayImage.overlay(image, cv_overlay_image74,point_list[74])
    image = CvOverlayImage.overlay(image, cv_overlay_image75,point_list[75])
    image = CvOverlayImage.overlay(image, cv_overlay_image76,point_list[76])    
    image = CvOverlayImage.overlay(image, cv_overlay_image77,point_list[77])
    image = CvOverlayImage.overlay(image, cv_overlay_image78,point_list[78])
    image = CvOverlayImage.overlay(image, cv_overlay_image79,point_list[79])
    image = CvOverlayImage.overlay(image, cv_overlay_image80,point_list[80])
    
    
    cv.imshow("Detection", image)
    cv.waitKey(0)
# Out:
# Only C and default locale supported with the posix collation implementation
# Only C and default locale supported with the posix collation implementation
# Case insensitive sorting unsupported in the posix collation implementation
# Numeric mode unsupported in the posix collation implementation
# Only C and default locale supported with the posix collation implementation
# Only C and default locale supported with the posix collation implementation
# Case insensitive sorting unsupported in the posix collation implementation
# Numeric mode unsupported in the posix collation implementation
# Only C and default locale supported with the posix collation implementation
# Only C and default locale supported with the posix collation implementation
# Case insensitive sorting unsupported in the posix collation implementation
# Numeric mode unsupported in the posix collation implementation
# Only C and default locale supported with the posix collation implementation
# ...
